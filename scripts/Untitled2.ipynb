# %%
import pandas as pd 
import numpy as np

# %%
df_train = pd.read_csv("../data/features_test.csv")

# %%
df_train.head()
# Out:
#    SK_ID_CURR  LIVINGAPARTMENTS_MODE  REGION_RATING_CLIENT  EXT_SOURCE_1  \
# 0      100001                 0.0000                     2      0.752614
# 1      100005                 0.0000                     2      0.564990
# 2      100013                 0.0000                     2      0.000000
# 3      100028                 0.2626                     2      0.525734
# 4      100038                 0.0000                     2      0.202145
#
#    APARTMENTS_MODE NAME_INCOME_TYPE  REG_CITY_NOT_LIVE_CITY  FLAG_DOCUMENT_7  \
# 0           0.0672          Working                       0                0
# 1           0.0000          Working                       0                0
# 2           0.0000          Working                       0                0
# 3           0.3109          Working                       0                0
# 4           0.0000          Working                       0                0
#
#    FLAG_DOCUMENT_11  LIVE_CITY_NOT_WORK_CITY  \
# ...
