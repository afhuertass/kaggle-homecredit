# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from  sklearn.preprocessing import LabelEncoder
from  sklearn.preprocessing import OneHotEncoder
import scipy 
from scipy.sparse import coo_matrix, hstack

from __future__ import division
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# %%
X = np.load( "../data/sparse/train_new.csv.npy")
X_test = np.load("../data/sparse/test_new.csv.npy" )

# %%
feat_labels = np.arange( X.shape[0] )

# %%
labels_train = pd.read_csv("../data/labels_train.csv", header = None )[1].values

# %%
X_train, X_test, y_train, y_test = train_test_split( X,  labels_train, test_size=0.4, random_state=0)

# %%
learning_rate = 0.1
num_leaves = 15
min_data_in_leaf = 2000
feature_fraction = 0.9
num_boost_round = 10000
params = {"objective": "binary",
          "boosting_type": "gbdt",
          "learning_rate": learning_rate,
          "metric":["auc" ,"binary_logloss"] , 
          "num_leaves": num_leaves,
           "max_bin": 256,
          "feature_fraction": feature_fraction,
          "verbosity": 0,
          "drop_rate": 0.1,
          "is_unbalance": True,
          "max_drop": 50,
          "min_child_samples": 10,
          "min_child_weight": 150,
          "min_split_gain": 0,
          "subsample": 0.9
}

# %%
NFOLDS = 5
kfold = StratifiedKFold(n_splits=NFOLDS, shuffle=True, random_state=218)
final_cv_train = np.zeros(len(labels_train))
final_cv_pred = np.zeros(len( X_test))
x_score = []
for s in xrange(16):
    cv_train = np.zeros(len(labels_train))
    cv_pred = np.zeros(len(X_test))

    params['seed'] = s

    if True:
        kf = kfold.split( X ,   labels_train )

        best_trees = []
        fold_scores = []

        for i, (train_fold, validate) in enumerate(kf):
            X_train, X_validate, label_train, label_validate = X[train_fold, :], X[validate, :], labels_train[train_fold], labels_train[validate]
            dtrain = lgb.Dataset(X_train, label_train)
            dvalid = lgb.Dataset(X_validate, label_validate, reference=dtrain)
            bst = lgb.train(params, dtrain, num_boost_round, valid_sets=dvalid , verbose_eval=100,early_stopping_rounds=100)
            best_trees.append(bst.best_iteration)
            cv_pred += bst.predict(X_test, num_iteration=bst.best_iteration)
            cv_train[validate] += bst.predict(X_validate)
            
            
            score = roc_auc_score( label_validate, cv_train[validate] )
            print( score )
            fold_scores.append(score)

        cv_pred /= NFOLDS
        final_cv_train += cv_train
        final_cv_pred += cv_pred

        print("cv score:")
        print roc_auc_score(labels_train, cv_train)
        print "current score:", roc_auc_score( labels_train , final_cv_train / (s + 1.)), s+1
        print(fold_scores)
        print(best_trees, np.mean(best_trees))

        x_score.append(roc_auc_score( labels_train , cv_train))
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.603812	valid_0's auc: 0.710271
# [200]	valid_0's binary_logloss: 0.579053	valid_0's auc: 0.719163
# [300]	valid_0's binary_logloss: 0.561839	valid_0's auc: 0.719873
# [400]	valid_0's binary_logloss: 0.546489	valid_0's auc: 0.719172
# Early stopping, best iteration is:
# [339]	valid_0's binary_logloss: 0.555673	valid_0's auc: 0.720215
# 0.7202149454900566
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.60546	valid_0's auc: 0.709878
# [200]	valid_0's binary_logloss: 0.581408	valid_0's auc: 0.717052
# [300]	valid_0's binary_logloss: 0.563946	valid_0's auc: 0.719065
# [400]	valid_0's binary_logloss: 0.548996	valid_0's auc: 0.719217
# [500]	valid_0's binary_logloss: 0.534752	valid_0's auc: 0.719564
# Early stopping, best iteration is:
# [459]	valid_0's binary_logloss: 0.540422	valid_0's auc: 0.719722
# 0.7197219135216482
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.60453	valid_0's auc: 0.708275
# [200]	valid_0's binary_logloss: 0.580482	valid_0's auc: 0.717307
# [300]	valid_0's binary_logloss: 0.56312	valid_0's auc: 0.718745
# Early stopping, best iteration is:
# [253]	valid_0's binary_logloss: 0.571023	valid_0's auc: 0.718875
# 0.7188745435819632
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605271	valid_0's auc: 0.711969
# [200]	valid_0's binary_logloss: 0.581056	valid_0's auc: 0.718712
# [300]	valid_0's binary_logloss: 0.563169	valid_0's auc: 0.720324
# [400]	valid_0's binary_logloss: 0.548361	valid_0's auc: 0.719303
# Early stopping, best iteration is:
# [335]	valid_0's binary_logloss: 0.557628	valid_0's auc: 0.720704
# 0.720703683767874
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605823	valid_0's auc: 0.710671
# [200]	valid_0's binary_logloss: 0.582054	valid_0's auc: 0.718873
# [300]	valid_0's binary_logloss: 0.564557	valid_0's auc: 0.720732
# [400]	valid_0's binary_logloss: 0.54928	valid_0's auc: 0.72099
# Early stopping, best iteration is:
# [353]	valid_0's binary_logloss: 0.556242	valid_0's auc: 0.721227
# 0.7212271064688434
# cv score:
# 0.7200346674401987
# current score: 0.7200346674401987 1
# [0.7202149454900566, 0.7197219135216482, 0.7188745435819632, 0.720703683767874, 0.7212271064688434]
# ([339, 459, 253, 335, 353], 347.8)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.603835	valid_0's auc: 0.710481
# [200]	valid_0's binary_logloss: 0.578629	valid_0's auc: 0.719572
# [300]	valid_0's binary_logloss: 0.560917	valid_0's auc: 0.72221
# [400]	valid_0's binary_logloss: 0.545994	valid_0's auc: 0.722174
# [500]	valid_0's binary_logloss: 0.532044	valid_0's auc: 0.721965
# Early stopping, best iteration is:
# [472]	valid_0's binary_logloss: 0.535916	valid_0's auc: 0.722462
# 0.722462412165501
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604947	valid_0's auc: 0.711323
# [200]	valid_0's binary_logloss: 0.580415	valid_0's auc: 0.719812
# [300]	valid_0's binary_logloss: 0.563021	valid_0's auc: 0.720861
# Early stopping, best iteration is:
# [283]	valid_0's binary_logloss: 0.565446	valid_0's auc: 0.721306
# 0.7213060573420527
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.60511	valid_0's auc: 0.707327
# [200]	valid_0's binary_logloss: 0.581073	valid_0's auc: 0.716545
# [300]	valid_0's binary_logloss: 0.563711	valid_0's auc: 0.717966
# [400]	valid_0's binary_logloss: 0.548572	valid_0's auc: 0.718315
# [500]	valid_0's binary_logloss: 0.534716	valid_0's auc: 0.718053
# Early stopping, best iteration is:
# [443]	valid_0's binary_logloss: 0.542432	valid_0's auc: 0.718987
# 0.7189869885491131
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605552	valid_0's auc: 0.711461
# [200]	valid_0's binary_logloss: 0.58156	valid_0's auc: 0.718708
# [300]	valid_0's binary_logloss: 0.563937	valid_0's auc: 0.720437
# Early stopping, best iteration is:
# [291]	valid_0's binary_logloss: 0.56526	valid_0's auc: 0.720616
# 0.7206161367184598
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605815	valid_0's auc: 0.713447
# [200]	valid_0's binary_logloss: 0.58147	valid_0's auc: 0.722146
# [300]	valid_0's binary_logloss: 0.563639	valid_0's auc: 0.723241
# [400]	valid_0's binary_logloss: 0.54846	valid_0's auc: 0.723505
# Early stopping, best iteration is:
# [362]	valid_0's binary_logloss: 0.553761	valid_0's auc: 0.724419
# 0.7244190629843755
# cv score:
# 0.7212778342791195
# current score: 0.7240882289024879 2
# [0.722462412165501, 0.7213060573420527, 0.7189869885491131, 0.7206161367184598, 0.7244190629843755]
# ([472, 283, 443, 291, 362], 370.2)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.603553	valid_0's auc: 0.710661
# [200]	valid_0's binary_logloss: 0.578793	valid_0's auc: 0.720134
# [300]	valid_0's binary_logloss: 0.561219	valid_0's auc: 0.720952
# [400]	valid_0's binary_logloss: 0.546025	valid_0's auc: 0.720771
# Early stopping, best iteration is:
# [351]	valid_0's binary_logloss: 0.552992	valid_0's auc: 0.721567
# 0.7215674068117774
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605345	valid_0's auc: 0.711372
# [200]	valid_0's binary_logloss: 0.581103	valid_0's auc: 0.719274
# [300]	valid_0's binary_logloss: 0.563221	valid_0's auc: 0.720284
# [400]	valid_0's binary_logloss: 0.5485	valid_0's auc: 0.719686
# Early stopping, best iteration is:
# [349]	valid_0's binary_logloss: 0.55561	valid_0's auc: 0.720567
# 0.7205670533716916
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604735	valid_0's auc: 0.707452
# [200]	valid_0's binary_logloss: 0.580935	valid_0's auc: 0.716858
# [300]	valid_0's binary_logloss: 0.563396	valid_0's auc: 0.718653
# [400]	valid_0's binary_logloss: 0.548386	valid_0's auc: 0.719178
# Early stopping, best iteration is:
# [387]	valid_0's binary_logloss: 0.550266	valid_0's auc: 0.719376
# 0.7193757900720434
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605434	valid_0's auc: 0.710988
# [200]	valid_0's binary_logloss: 0.581089	valid_0's auc: 0.71919
# [300]	valid_0's binary_logloss: 0.563443	valid_0's auc: 0.720584
# [400]	valid_0's binary_logloss: 0.548429	valid_0's auc: 0.720763
# Early stopping, best iteration is:
# [324]	valid_0's binary_logloss: 0.559562	valid_0's auc: 0.721137
# 0.7211374290782065
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.606122	valid_0's auc: 0.710837
# [200]	valid_0's binary_logloss: 0.581925	valid_0's auc: 0.719245
# [300]	valid_0's binary_logloss: 0.564049	valid_0's auc: 0.721199
# [400]	valid_0's binary_logloss: 0.548646	valid_0's auc: 0.721873
# Early stopping, best iteration is:
# [386]	valid_0's binary_logloss: 0.550483	valid_0's auc: 0.722012
# 0.7220121763963144
# cv score:
# 0.7209063338660806
# current score: 0.7251982148316696 3
# [0.7215674068117774, 0.7205670533716916, 0.7193757900720434, 0.7211374290782065, 0.7220121763963144]
# ([351, 349, 387, 324, 386], 359.4)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604322	valid_0's auc: 0.70928
# [200]	valid_0's binary_logloss: 0.579196	valid_0's auc: 0.719679
# [300]	valid_0's binary_logloss: 0.561379	valid_0's auc: 0.721363
# [400]	valid_0's binary_logloss: 0.545966	valid_0's auc: 0.721576
# Early stopping, best iteration is:
# [337]	valid_0's binary_logloss: 0.555443	valid_0's auc: 0.722159
# 0.7221588617225313
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605153	valid_0's auc: 0.711068
# [200]	valid_0's binary_logloss: 0.580989	valid_0's auc: 0.718813
# [300]	valid_0's binary_logloss: 0.563146	valid_0's auc: 0.720677
# Early stopping, best iteration is:
# [299]	valid_0's binary_logloss: 0.563284	valid_0's auc: 0.720774
# 0.7207736501585349
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604655	valid_0's auc: 0.707851
# [200]	valid_0's binary_logloss: 0.580789	valid_0's auc: 0.717456
# [300]	valid_0's binary_logloss: 0.563026	valid_0's auc: 0.719456
# [400]	valid_0's binary_logloss: 0.548013	valid_0's auc: 0.71966
# Early stopping, best iteration is:
# [357]	valid_0's binary_logloss: 0.554341	valid_0's auc: 0.720198
# 0.7201979094120844
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605355	valid_0's auc: 0.710566
# [200]	valid_0's binary_logloss: 0.580962	valid_0's auc: 0.720017
# [300]	valid_0's binary_logloss: 0.563384	valid_0's auc: 0.721019
# [400]	valid_0's binary_logloss: 0.548099	valid_0's auc: 0.720611
# Early stopping, best iteration is:
# [316]	valid_0's binary_logloss: 0.560675	valid_0's auc: 0.721539
# 0.7215389627742643
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605867	valid_0's auc: 0.711866
# [200]	valid_0's binary_logloss: 0.581555	valid_0's auc: 0.720803
# [300]	valid_0's binary_logloss: 0.563822	valid_0's auc: 0.722626
# [400]	valid_0's binary_logloss: 0.549024	valid_0's auc: 0.722206
# Early stopping, best iteration is:
# [333]	valid_0's binary_logloss: 0.558694	valid_0's auc: 0.723153
# 0.7231533944894449
# cv score:
# 0.7215240784812366
# current score: 0.7258800388866409 4
# [0.7221588617225313, 0.7207736501585349, 0.7201979094120844, 0.7215389627742643, 0.7231533944894449]
# ([337, 299, 357, 316, 333], 328.4)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.603963	valid_0's auc: 0.709408
# [200]	valid_0's binary_logloss: 0.579167	valid_0's auc: 0.719348
# [300]	valid_0's binary_logloss: 0.561557	valid_0's auc: 0.720516
# [400]	valid_0's binary_logloss: 0.546225	valid_0's auc: 0.720725
# Early stopping, best iteration is:
# [382]	valid_0's binary_logloss: 0.548943	valid_0's auc: 0.720835
# 0.7208352663700558
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605575	valid_0's auc: 0.710784
# [200]	valid_0's binary_logloss: 0.581728	valid_0's auc: 0.717886
# [300]	valid_0's binary_logloss: 0.564321	valid_0's auc: 0.719374
# [400]	valid_0's binary_logloss: 0.549109	valid_0's auc: 0.71901
# Early stopping, best iteration is:
# [319]	valid_0's binary_logloss: 0.561177	valid_0's auc: 0.719771
# 0.7197709078073282
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604858	valid_0's auc: 0.706514
# [200]	valid_0's binary_logloss: 0.580374	valid_0's auc: 0.715944
# [300]	valid_0's binary_logloss: 0.562989	valid_0's auc: 0.718059
# [400]	valid_0's binary_logloss: 0.547416	valid_0's auc: 0.718483
# Early stopping, best iteration is:
# [357]	valid_0's binary_logloss: 0.553842	valid_0's auc: 0.718984
# 0.7189835899779985
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605343	valid_0's auc: 0.711472
# [200]	valid_0's binary_logloss: 0.581047	valid_0's auc: 0.71939
# [300]	valid_0's binary_logloss: 0.563454	valid_0's auc: 0.720435
# [400]	valid_0's binary_logloss: 0.548338	valid_0's auc: 0.720475
# [500]	valid_0's binary_logloss: 0.534612	valid_0's auc: 0.719991
# Early stopping, best iteration is:
# [416]	valid_0's binary_logloss: 0.545885	valid_0's auc: 0.720807
# 0.7208069981922915
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.606008	valid_0's auc: 0.711997
# [200]	valid_0's binary_logloss: 0.581694	valid_0's auc: 0.720004
# [300]	valid_0's binary_logloss: 0.564379	valid_0's auc: 0.721593
# [400]	valid_0's binary_logloss: 0.549346	valid_0's auc: 0.721512
# Early stopping, best iteration is:
# [303]	valid_0's binary_logloss: 0.563857	valid_0's auc: 0.721744
# 0.7217444694533917
# cv score:
# 0.7203400807698561
# current score: 0.7261055682654779 5
# [0.7208352663700558, 0.7197709078073282, 0.7189835899779985, 0.7208069981922915, 0.7217444694533917]
# ([382, 319, 357, 416, 303], 355.4)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.603979	valid_0's auc: 0.708998
# [200]	valid_0's binary_logloss: 0.579478	valid_0's auc: 0.718797
# [300]	valid_0's binary_logloss: 0.561553	valid_0's auc: 0.720867
# [400]	valid_0's binary_logloss: 0.546861	valid_0's auc: 0.72042
# Early stopping, best iteration is:
# [303]	valid_0's binary_logloss: 0.561101	valid_0's auc: 0.720964
# 0.7209642637305811
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605433	valid_0's auc: 0.710564
# [200]	valid_0's binary_logloss: 0.580863	valid_0's auc: 0.718685
# [300]	valid_0's binary_logloss: 0.563387	valid_0's auc: 0.719913
# Early stopping, best iteration is:
# [288]	valid_0's binary_logloss: 0.565292	valid_0's auc: 0.720028
# 0.7200279309821456
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604681	valid_0's auc: 0.707963
# [200]	valid_0's binary_logloss: 0.580926	valid_0's auc: 0.717161
# [300]	valid_0's binary_logloss: 0.563251	valid_0's auc: 0.719345
# [400]	valid_0's binary_logloss: 0.548041	valid_0's auc: 0.719534
# Early stopping, best iteration is:
# [361]	valid_0's binary_logloss: 0.553648	valid_0's auc: 0.720077
# 0.7200771461393238
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605242	valid_0's auc: 0.710962
# [200]	valid_0's binary_logloss: 0.581072	valid_0's auc: 0.718738
# [300]	valid_0's binary_logloss: 0.563444	valid_0's auc: 0.718864
# [400]	valid_0's binary_logloss: 0.548438	valid_0's auc: 0.719042
# Early stopping, best iteration is:
# [357]	valid_0's binary_logloss: 0.554536	valid_0's auc: 0.71927
# 0.719269786002771
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605801	valid_0's auc: 0.713149
# [200]	valid_0's binary_logloss: 0.581258	valid_0's auc: 0.72157
# [300]	valid_0's binary_logloss: 0.563953	valid_0's auc: 0.722516
# [400]	valid_0's binary_logloss: 0.548495	valid_0's auc: 0.722778
# Early stopping, best iteration is:
# [398]	valid_0's binary_logloss: 0.548722	valid_0's auc: 0.722922
# 0.7229224377138368
# cv score:
# 0.7205890718912025
# current score: 0.7262620139865456 6
# [0.7209642637305811, 0.7200279309821456, 0.7200771461393238, 0.719269786002771, 0.7229224377138368]
# ([303, 288, 361, 357, 398], 341.4)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.603583	valid_0's auc: 0.710293
# [200]	valid_0's binary_logloss: 0.578892	valid_0's auc: 0.719711
# [300]	valid_0's binary_logloss: 0.561333	valid_0's auc: 0.720681
# [400]	valid_0's binary_logloss: 0.545959	valid_0's auc: 0.721265
# Early stopping, best iteration is:
# [396]	valid_0's binary_logloss: 0.546527	valid_0's auc: 0.721444
# 0.7214444369990691
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605923	valid_0's auc: 0.70874
# [200]	valid_0's binary_logloss: 0.581117	valid_0's auc: 0.716809
# [300]	valid_0's binary_logloss: 0.563701	valid_0's auc: 0.71799
# Early stopping, best iteration is:
# [261]	valid_0's binary_logloss: 0.569941	valid_0's auc: 0.718481
# 0.7184811856937755
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605103	valid_0's auc: 0.707435
# [200]	valid_0's binary_logloss: 0.581352	valid_0's auc: 0.716514
# [300]	valid_0's binary_logloss: 0.563601	valid_0's auc: 0.719247
# [400]	valid_0's binary_logloss: 0.548482	valid_0's auc: 0.719367
# Early stopping, best iteration is:
# [360]	valid_0's binary_logloss: 0.554355	valid_0's auc: 0.719861
# 0.7198605780730781
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.60532	valid_0's auc: 0.711503
# [200]	valid_0's binary_logloss: 0.580593	valid_0's auc: 0.719761
# [300]	valid_0's binary_logloss: 0.563028	valid_0's auc: 0.720471
# [400]	valid_0's binary_logloss: 0.547973	valid_0's auc: 0.720568
# Early stopping, best iteration is:
# [371]	valid_0's binary_logloss: 0.551987	valid_0's auc: 0.720847
# 0.7208473499900011
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605263	valid_0's auc: 0.712986
# [200]	valid_0's binary_logloss: 0.581095	valid_0's auc: 0.720887
# [300]	valid_0's binary_logloss: 0.563996	valid_0's auc: 0.720897
# [400]	valid_0's binary_logloss: 0.54865	valid_0's auc: 0.721998
# [500]	valid_0's binary_logloss: 0.534972	valid_0's auc: 0.722006
# Early stopping, best iteration is:
# [438]	valid_0's binary_logloss: 0.543172	valid_0's auc: 0.722531
# 0.7225314061012652
# cv score:
# 0.7204791740324379
# current score: 0.726394237884844 7
# [0.7214444369990691, 0.7184811856937755, 0.7198605780730781, 0.7208473499900011, 0.7225314061012652]
# ([396, 261, 360, 371, 438], 365.2)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604167	valid_0's auc: 0.709609
# [200]	valid_0's binary_logloss: 0.578961	valid_0's auc: 0.719844
# [300]	valid_0's binary_logloss: 0.561383	valid_0's auc: 0.721369
# Early stopping, best iteration is:
# [264]	valid_0's binary_logloss: 0.56723	valid_0's auc: 0.721527
# 0.7215274369024931
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605334	valid_0's auc: 0.710092
# [200]	valid_0's binary_logloss: 0.580734	valid_0's auc: 0.718771
# [300]	valid_0's binary_logloss: 0.563201	valid_0's auc: 0.71996
# [400]	valid_0's binary_logloss: 0.54835	valid_0's auc: 0.719548
# Early stopping, best iteration is:
# [348]	valid_0's binary_logloss: 0.55601	valid_0's auc: 0.720136
# 0.7201359513944483
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604993	valid_0's auc: 0.707191
# [200]	valid_0's binary_logloss: 0.58114	valid_0's auc: 0.716033
# [300]	valid_0's binary_logloss: 0.563682	valid_0's auc: 0.717185
# [400]	valid_0's binary_logloss: 0.548501	valid_0's auc: 0.718227
# [500]	valid_0's binary_logloss: 0.534358	valid_0's auc: 0.71823
# Early stopping, best iteration is:
# [435]	valid_0's binary_logloss: 0.543238	valid_0's auc: 0.718719
# 0.7187187614894369
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605118	valid_0's auc: 0.711696
# [200]	valid_0's binary_logloss: 0.581577	valid_0's auc: 0.71728
# [300]	valid_0's binary_logloss: 0.563755	valid_0's auc: 0.717797
# [400]	valid_0's binary_logloss: 0.548538	valid_0's auc: 0.718044
# Early stopping, best iteration is:
# [365]	valid_0's binary_logloss: 0.553685	valid_0's auc: 0.718528
# 0.7185282348852958
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605782	valid_0's auc: 0.712156
# [200]	valid_0's binary_logloss: 0.581552	valid_0's auc: 0.720553
# [300]	valid_0's binary_logloss: 0.563948	valid_0's auc: 0.721657
# [400]	valid_0's binary_logloss: 0.548989	valid_0's auc: 0.721539
# Early stopping, best iteration is:
# [327]	valid_0's binary_logloss: 0.55976	valid_0's auc: 0.722006
# 0.7220058851210645
# cv score:
# 0.7200507890075551
# current score: 0.7264379372273881 8
# [0.7215274369024931, 0.7201359513944483, 0.7187187614894369, 0.7185282348852958, 0.7220058851210645]
# ([264, 348, 435, 365, 327], 347.8)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604177	valid_0's auc: 0.709706
# [200]	valid_0's binary_logloss: 0.57966	valid_0's auc: 0.718334
# [300]	valid_0's binary_logloss: 0.562211	valid_0's auc: 0.719452
# [400]	valid_0's binary_logloss: 0.547069	valid_0's auc: 0.719749
# Early stopping, best iteration is:
# [397]	valid_0's binary_logloss: 0.547444	valid_0's auc: 0.719779
# 0.7197793874750334
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.606124	valid_0's auc: 0.710005
# [200]	valid_0's binary_logloss: 0.58197	valid_0's auc: 0.717576
# [300]	valid_0's binary_logloss: 0.564276	valid_0's auc: 0.718739
# [400]	valid_0's binary_logloss: 0.548973	valid_0's auc: 0.719258
# Early stopping, best iteration is:
# [376]	valid_0's binary_logloss: 0.552341	valid_0's auc: 0.719598
# 0.71959834660584
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604555	valid_0's auc: 0.70803
# [200]	valid_0's binary_logloss: 0.580679	valid_0's auc: 0.716626
# [300]	valid_0's binary_logloss: 0.56291	valid_0's auc: 0.719416
# [400]	valid_0's binary_logloss: 0.547861	valid_0's auc: 0.720492
# [500]	valid_0's binary_logloss: 0.534187	valid_0's auc: 0.720306
# Early stopping, best iteration is:
# [460]	valid_0's binary_logloss: 0.539314	valid_0's auc: 0.720825
# 0.7208248567216389
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605393	valid_0's auc: 0.711493
# [200]	valid_0's binary_logloss: 0.581208	valid_0's auc: 0.718402
# [300]	valid_0's binary_logloss: 0.563469	valid_0's auc: 0.720068
# [400]	valid_0's binary_logloss: 0.54819	valid_0's auc: 0.719952
# Early stopping, best iteration is:
# [335]	valid_0's binary_logloss: 0.557848	valid_0's auc: 0.720738
# 0.7207376196048106
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.606084	valid_0's auc: 0.711167
# [200]	valid_0's binary_logloss: 0.581666	valid_0's auc: 0.721284
# [300]	valid_0's binary_logloss: 0.563961	valid_0's auc: 0.723858
# [400]	valid_0's binary_logloss: 0.549264	valid_0's auc: 0.723269
# Early stopping, best iteration is:
# [309]	valid_0's binary_logloss: 0.562407	valid_0's auc: 0.724145
# 0.72414501132955
# cv score:
# 0.7208627465263645
# current score: 0.7265769147822136 9
# [0.7197793874750334, 0.71959834660584, 0.7208248567216389, 0.7207376196048106, 0.72414501132955]
# ([397, 376, 460, 335, 309], 375.4)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604054	valid_0's auc: 0.708647
# [200]	valid_0's binary_logloss: 0.579077	valid_0's auc: 0.718555
# [300]	valid_0's binary_logloss: 0.561558	valid_0's auc: 0.719816
# [400]	valid_0's binary_logloss: 0.54622	valid_0's auc: 0.719604
# Early stopping, best iteration is:
# [350]	valid_0's binary_logloss: 0.553455	valid_0's auc: 0.720605
# 0.7206046984165254
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605333	valid_0's auc: 0.710366
# [200]	valid_0's binary_logloss: 0.580784	valid_0's auc: 0.719047
# [300]	valid_0's binary_logloss: 0.563744	valid_0's auc: 0.718918
# Early stopping, best iteration is:
# [213]	valid_0's binary_logloss: 0.578326	valid_0's auc: 0.71928
# 0.719279643283981
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604793	valid_0's auc: 0.707569
# [200]	valid_0's binary_logloss: 0.580493	valid_0's auc: 0.717779
# [300]	valid_0's binary_logloss: 0.562822	valid_0's auc: 0.719775
# [400]	valid_0's binary_logloss: 0.547557	valid_0's auc: 0.720279
# Early stopping, best iteration is:
# [383]	valid_0's binary_logloss: 0.549936	valid_0's auc: 0.720729
# 0.7207291730512335
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605246	valid_0's auc: 0.710561
# [200]	valid_0's binary_logloss: 0.581328	valid_0's auc: 0.718579
# [300]	valid_0's binary_logloss: 0.564115	valid_0's auc: 0.719679
# [400]	valid_0's binary_logloss: 0.548422	valid_0's auc: 0.72029
# Early stopping, best iteration is:
# [353]	valid_0's binary_logloss: 0.55555	valid_0's auc: 0.720601
# 0.7206012777665531
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605727	valid_0's auc: 0.712204
# [200]	valid_0's binary_logloss: 0.581269	valid_0's auc: 0.722366
# [300]	valid_0's binary_logloss: 0.563823	valid_0's auc: 0.722981
# [400]	valid_0's binary_logloss: 0.548841	valid_0's auc: 0.722594
# Early stopping, best iteration is:
# [325]	valid_0's binary_logloss: 0.55977	valid_0's auc: 0.723653
# 0.7236529452564113
# cv score:
# 0.7207788537007875
# current score: 0.7266405358084191 10
# [0.7206046984165254, 0.719279643283981, 0.7207291730512335, 0.7206012777665531, 0.7236529452564113]
# ([350, 213, 383, 353, 325], 324.8)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.603965	valid_0's auc: 0.710296
# [200]	valid_0's binary_logloss: 0.578997	valid_0's auc: 0.719888
# [300]	valid_0's binary_logloss: 0.561593	valid_0's auc: 0.721351
# [400]	valid_0's binary_logloss: 0.546554	valid_0's auc: 0.721967
# Early stopping, best iteration is:
# [372]	valid_0's binary_logloss: 0.550436	valid_0's auc: 0.722017
# 0.7220173782183303
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605733	valid_0's auc: 0.710529
# [200]	valid_0's binary_logloss: 0.581585	valid_0's auc: 0.71798
# [300]	valid_0's binary_logloss: 0.564077	valid_0's auc: 0.719336
# [400]	valid_0's binary_logloss: 0.549278	valid_0's auc: 0.718464
# Early stopping, best iteration is:
# [316]	valid_0's binary_logloss: 0.561465	valid_0's auc: 0.71974
# 0.7197403313546276
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604628	valid_0's auc: 0.707904
# [200]	valid_0's binary_logloss: 0.580789	valid_0's auc: 0.717604
# [300]	valid_0's binary_logloss: 0.563257	valid_0's auc: 0.719177
# [400]	valid_0's binary_logloss: 0.547807	valid_0's auc: 0.719348
# Early stopping, best iteration is:
# [351]	valid_0's binary_logloss: 0.555073	valid_0's auc: 0.719817
# 0.7198168312666976
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.604884	valid_0's auc: 0.71227
# [200]	valid_0's binary_logloss: 0.580929	valid_0's auc: 0.719554
# [300]	valid_0's binary_logloss: 0.563602	valid_0's auc: 0.720013
# Early stopping, best iteration is:
# [293]	valid_0's binary_logloss: 0.56478	valid_0's auc: 0.720144
# 0.7201439348303682
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605725	valid_0's auc: 0.712691
# [200]	valid_0's binary_logloss: 0.581529	valid_0's auc: 0.72159
# [300]	valid_0's binary_logloss: 0.563954	valid_0's auc: 0.72349
# [400]	valid_0's binary_logloss: 0.548736	valid_0's auc: 0.723723
# Early stopping, best iteration is:
# [352]	valid_0's binary_logloss: 0.555872	valid_0's auc: 0.724167
# 0.7241665641128239
# cv score:
# 0.7211239995349175
# current score: 0.7267232859486561 11
# [0.7220173782183303, 0.7197403313546276, 0.7198168312666976, 0.7201439348303682, 0.7241665641128239]
# ([372, 316, 351, 293, 352], 336.8)
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.603671	valid_0's auc: 0.709824
# [200]	valid_0's binary_logloss: 0.579057	valid_0's auc: 0.71845
# [300]	valid_0's binary_logloss: 0.561212	valid_0's auc: 0.720836
# [400]	valid_0's binary_logloss: 0.546151	valid_0's auc: 0.720236
# Early stopping, best iteration is:
# [343]	valid_0's binary_logloss: 0.554104	valid_0's auc: 0.721503
# 0.7215033124617022
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605769	valid_0's auc: 0.709904
# [200]	valid_0's binary_logloss: 0.581502	valid_0's auc: 0.717364
# [300]	valid_0's binary_logloss: 0.563798	valid_0's auc: 0.718009
# [400]	valid_0's binary_logloss: 0.548603	valid_0's auc: 0.718604
# [500]	valid_0's binary_logloss: 0.534713	valid_0's auc: 0.717998
# Early stopping, best iteration is:
# [464]	valid_0's binary_logloss: 0.539598	valid_0's auc: 0.718695
# 0.718695470233727
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605349	valid_0's auc: 0.706724
# [200]	valid_0's binary_logloss: 0.581065	valid_0's auc: 0.716347
# [300]	valid_0's binary_logloss: 0.563862	valid_0's auc: 0.71853
# [400]	valid_0's binary_logloss: 0.548434	valid_0's auc: 0.719708
# Early stopping, best iteration is:
# [393]	valid_0's binary_logloss: 0.549461	valid_0's auc: 0.719807
# 0.7198065464922658
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.605493	valid_0's auc: 0.711846
# [200]	valid_0's binary_logloss: 0.581549	valid_0's auc: 0.719296
# [300]	valid_0's binary_logloss: 0.563391	valid_0's auc: 0.720249
# [400]	valid_0's binary_logloss: 0.547954	valid_0's auc: 0.719729
# Early stopping, best iteration is:
# [310]	valid_0's binary_logloss: 0.561619	valid_0's auc: 0.720513
# 0.7205131642886198
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's binary_logloss: 0.606376	valid_0's auc: 0.711878
# [200]	valid_0's binary_logloss: 0.581926	valid_0's auc: 0.721438
# [300]	valid_0's binary_logloss: 0.564534	valid_0's auc: 0.72265
# [400]	valid_0's binary_logloss: 0.549187	valid_0's auc: 0.723539
# [500]	valid_0's binary_logloss: 0.535589	valid_0's auc: 0.722843
# Early stopping, best iteration is:
# [403]	valid_0's binary_logloss: 0.548765	valid_0's auc: 0.723603
# 0.7236033596051075
# cv score:
# 0.7207430184957352
# current score: 0.7268079140599737 12
# [0.7215033124617022, 0.718695470233727, 0.7198065464922658, 0.7205131642886198, 0.7236033596051075]
# ([343, 464, 393, 310, 403], 382.6)
# Training until validation scores don't improve for 100 rounds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-dfc388d55f02> in <module>()
#      20             dtrain = lgb.Dataset(X_train, label_train)
#      21             dvalid = lgb.Dataset(X_validate, label_validate, reference=dtrain)
# ---> 22             bst = lgb.train(params, dtrain, num_boost_round, valid_sets=dvalid , verbose_eval=100,early_stopping_rounds=100)
#      23             best_trees.append(bst.best_iteration)
#      24             cv_pred += bst.predict(X_test, num_iteration=bst.best_iteration)
#
# /usr/local/lib/python2.7/dist-packages/lightgbm/engine.pyc in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     199                                     evaluation_result_list=None))
#     200
# --> 201         booster.update(fobj=fobj)
#     202
#     203         evaluation_result_list = []
#
# /usr/local/lib/python2.7/dist-packages/lightgbm/basic.pyc in update(self, train_set, fobj)
#    1522             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1523                 self.handle,
# -> 1524                 ctypes.byref(is_finished)))
#    1525             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1526             return is_finished.value == 1
#
# KeyboardInterrupt:
